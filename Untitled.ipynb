# %%
import json
from copy import deepcopy

# %%
claim_damages = json.loads("""
[
  {
    "claim_id": "310b4383-1e47-4aa5-86bf-d19615973a8d",
    "claim_title": "Abuse of Process",
    "elements": [
      "Defendant willfully or intentionally made illegal, improper, or perverted use of process;",
      "Defendant had ulterior motive or purpose in exercising the process; and",
      "Defendant\u2019s actions caused injury to plaintiff."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "406",
    "burden_of_proof": "406.9",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Use malicious prosecution pattern",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "d0cfbabf-84e9-4063-894f-da1fcb7f6a01",
    "claim_title": "Account Stated",
    "elements": [
      "Plaintiff and defendant made a previous transaction;",
      "The parties\u2019 agreement that the balance is correct and due; and",
      "Defendant made an express or implicit promise to pay balance."
    ],
    "element_count": 3,
    "verdict_form": "416.39",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Account Stated",
    "has_explicit_template": true
  },
  {
    "claim_id": "060dd553-b3dd-4617-bff2-98020e27e13d",
    "claim_title": "Accounting",
    "elements": [
      "Plaintiff and defendant share a fiduciary relationship or entered a complex transaction; and",
      "A remedy at law is inadequate."
    ],
    "element_count": 2,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "b5ce95d1-9b99-46db-a405-711c0e18cf14",
    "claim_title": "Assault",
    "elements": [
      "Defendant made an intentional, unlawful offer of corporal injury to plaintiff by force, or force unlawfully directed toward plaintiff\u2019s person;",
      "Defendant\u2019s actions created a fear of imminent peril; and",
      "Defendant had the apparent present ability to effectuate the attempted action."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "ab1de924-7054-44a6-bde9-6bbcb27f7869",
    "claim_title": "Battery",
    "elements": [
      "Defendant committed acts intending to cause harmful or offensive contact with plaintiff or causing plaintiff to be in imminent apprehension of such a contact; and",
      "Defendant made an offensive contact with plaintiff."
    ],
    "element_count": 2,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "d2aa7d91-adb7-4d1e-8d43-9fba98c211d3",
    "claim_title": "Breach: 01. Breach of Contract",
    "elements": [
      "Plaintiff and defendant entered a valid contract;",
      "Defendant committed a material breach of the contract; and",
      "Plaintiff suffered damages caused by defendant\u2019s breach."
    ],
    "element_count": 3,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2",
      "504.3"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "d88d175a-27a2-4365-abf8-a7757bc459e0",
    "claim_title": "Breach: 02. Breach of Joint Venture Agreement",
    "elements": [
      "The elements of an ordinary contract;",
      "Community of interests in the performance of the common purpose;",
      "Joint control or right of control;",
      "Joint proprietary interest in the subject matter;",
      "Right to share in the profits; and",
      "Duty to share in the losses."
    ],
    "element_count": 6,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2",
      "504.3"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Adapt breach of contract form for joint venture context",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "84c4a2f6-9111-42bc-a7ad-92046f19c4c0",
    "claim_title": "Breach: 03. Breach of Promissory Note",
    "elements": [
      "Fla. R. Civ. P. 1.110(d) (pleading affirmative defenses), and other standard defenses. See \u00a7 1.",
      "Statute of Limitations:\u00a7 95.11(2)(b), Fla. Stat. (five yearsfor written contract); \u00a7 95.11(3)(k), Fla. Stat. (four yearsfor oral contract);see alsoGonzalez-Guzman v. Metropolitan Life Ins. Co., No. 17-20107-CIV-GAYLES, 2017 WL 4882512, at *3 (S.D. Fla. Oct. 30, 2017)(discussing the statute of limitations for written contracts).",

    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "349efdb5-3eef-4642-ab5e-9e74a54bf6ea",
    "claim_title": "Breach: 04. Breach of Third-Party Beneficiary Contract",
    "elements": [
      "Defendant and a third-party entered a valid contract;",
      "Plaintiff is not a party to the contract;",
      "The parties to the contract intended that the contract primarily or directly benefit plaintiff or a class of parties of which plaintiff is a member;",
      "The contract is breached;",
      "Plaintiff suffered damages as a result of the breach."
    ],
    "element_count": 5,
    "verdict_form": "416.2",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Third-Party Beneficiary of Contract Claim",
    "has_explicit_template": true
  },
  {
    "claim_id": "13d6374d-bdce-45db-aed4-a3cd7d55dcde",
    "claim_title": "Breach: 05. Breach of Implied in Fact Contract",
    "elements": [
      "A valid contract existed between Plaintiff and Defendant;",
      "Some or all of the contract terms were inferred from the parties\u2019 conduct, not written;",
      "Defendant materially breached the contract; and",
      "Plaintiff suffered damages as a result of the breach."
    ],
    "element_count": 4,
    "verdict_form": "416.6",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Contract Implied in Fact",
    "has_explicit_template": true
  },
  {
    "claim_id": "c5e8e463-f356-468d-9b2c-7d191f4586a8",
    "claim_title": "Breach: 06. Breach of Implied in Law Contract",
    "elements": [
      "Plaintiff conferred a benefit upon Defendant;",
      "Defendant appreciated the benefit;",
      "Defendant accepted and retained the benefit without paying the value thereof; and",
      "The circumstances are such that it is inequitable for Defendant to retain the benefit without paying fair value for it."
    ],
    "element_count": 4,
    "verdict_form": "416.7",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Contract Implied in Law",
    "has_explicit_template": true
  },
  {
    "claim_id": "1265eff3-e1fc-4726-859b-2a78a5542cae",
    "claim_title": "Breach: 07. Breach Implied Covenant of Good Faith & Fair Dealing",
    "elements": [
      "Plaintiff and Defendant are parties to a written contract:",
      "The contract is ambiguous about the permissibility or scope of the conduct in question;",
      "Defendant, through a conscious and deliberate act, fails or refuses to discharge contractual responsibilities that unfairly frustrates the contract\u2019s purpose and disappoints the Plaintiff\u2019s expectations;",
      "Defendant\u2019s breach deprives the Plaintiff of the contract\u2019s benefits; and",
      "Plaintiff suffers damages."
    ],
    "element_count": 5,
    "verdict_form": "416.24",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Implied Covenant of Good Faith and Fair Dealing",
    "has_explicit_template": true
  },
  {
    "claim_id": "ab45c2bd-f845-4881-b3f7-67f0aa77822d",
    "claim_title": "Breach: 08. Breach of Express Warranty",
    "elements": [
      "Plaintiff purchased a product;",
      "Defendant provided an express warranty by affirmation of fact or promise, or description of the product;",
      "The product failed to conform to the defendant\u2019s affirmation or description; and",
      "Plaintiff suffered damages caused by the defendant\u2019s breach."
    ],
    "element_count": 4,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Adapt breach of contract; may need UCC instructions",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "19163340-46db-4e7c-805d-cd05456e4d24",
    "claim_title": "Breach: 09. Breach of Implied Warranty",
    "elements": [
      "Plaintiff purchased a product;",
      "Plaintiff was a foreseeable user of the product;",
      "Plaintiff was using the product in the intended manner at the time of the injury;",
      "The product was defective when transferred from the warrantor; and",
      "The defect caused the plaintiff\u2019s injury."
    ],
    "element_count": 5,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Adapt breach of contract; may need UCC instructions",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "b615205e-5bb7-4b45-9765-23ac2f76854a",
    "claim_title": "Breach: 10. Breach of Implied Warranty of Fitness for a Particular Purpose",
    "elements": [
      "Plaintiff purchased a product;",
      "The defendant at the time of contracting had reason to know the particular purpose for which the buyer purchased the product;",
      "Plaintiff relied on the defendant\u2019s judgment in providing a suitable product;",
      "The product failed to be fit for its particular purpose; and",
      "Plaintiff suffered damages caused by the defendant\u2019s breach."
    ],
    "element_count": 5,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Adapt breach of contract; may need UCC instructions",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "6de665d7-9de0-4dbe-89da-d9f3b60e9961",
    "claim_title": "Breach: 11. Breach of Fiduciary Duty",
    "elements": [
      "Plaintiff and Defendant share a relationship whereby:(a) Plaintiff reposes trust and confidence in Defendant, and(b) Defendant undertakes such trust and assumes a duty to advise, counsel and/or protect Plaintiff;",
      "Defendant breaches its duties to Plaintiff; and",
      "Plaintiff suffers damages."
    ],
    "element_count": 3,
    "verdict_form": "451.14",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "fiduciary",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Fiduciary Duty",
    "has_explicit_template": true
  },
  {
    "claim_id": "921585e7-e1a9-4869-8289-4873ca8df7d4",
    "claim_title": "Breach: 12. Breach of Fiduciary Duty, Aiding and Abetting",
    "elements": [
      "a fiduciary duty on the part of a primary wrongdoer;",
      "a breach of that fiduciary duty;",
      "knowledge of the breach by the alleged aider and abettor; and",
      "the aider and abettor\u2019s substantial assistance or encouragement of the wrongdoing.\u201d"
    ],
    "element_count": 4,
    "verdict_form": "451.14",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "fiduciary",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Adapt fiduciary duty form; add aiding/abetting elements",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Fiduciary Duty",
    "has_explicit_template": true
  },
  {
    "claim_id": "ac049dec-f19d-47e0-96ca-5daa263bb54f",
    "claim_title": "Building Code, Violation of",
    "elements": [
      "R. Civ. P. 1.110(d) (pleading affirmative defenses), and other standard defenses. See \u00a7 1.",
      "Statute of Limitations:95.11(3)(c), Fla. Stat. (2023) (four years).Westpark Pres. Homeowners Ass\u2019n, Inc. v. Pulte Home Corp., 2023 WL 3325821, *3 (Fla. 2d DCA May 10, 2023) (citingSnyder v. Wernecke, 813 So. 2d 213, 216 (Fla. 4th DCA 2002)).",
      "\u201cAlthough the South Florida building code provides that compliance is the responsibility of the owner,the code does not impose a duty on a landowner to superviseconstruction undertaken by an independent contractor.\u201dSierra v. Allied Stores Corp., 538 So. 2d 943, 944 (Fla. 3d DCA 1989)(emphasis added);Brown v. S. Broward Hosp. Dist., 402 So. 2d 58, 60 (Fla. 4th DCA 1981).",
      "To be exempt from liability, a party has theburden of provingthat the building code was not violated.Gozzo Dev., Inc. v. Esker, 199 So. 3d 940, 941 (Fla. 4th DCA 2016).",
      "Section 553.84 \u201cprovides adefense to any builder that obtained the required permits, approvals, and inspections, unless (1) the violation caused a personal injury or injury to property besides the property that had been the subject of the permits, plans, and inspections or (2) the builder knew or should have known of the violation.\u201dGazzara v. Pulte Home Corp., 2016 WL 7188893, *3 (M.D. Fla. Dec. 12, 2016)(emphasis added)."
    ],
    "element_count": 5,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "0a380d87-52e2-41c2-8ce6-f3c22834779a",
    "claim_title": "Civil Conspiracy",
    "elements": [
      "A conspiracy between two or more parties;",
      "To do an unlawful act or to do a lawful act by unlawful means;",
      "The execution of some overt act in pursuance of the conspiracy; and",
      "Plaintiff suffers damage as a result of the acts performed through the conspiracy."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Requires underlying tort",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "7c3115f4-3d6c-482d-803c-f41d9fd9d9fd",
    "claim_title": "Civil Theft",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": "411",
    "burden_of_proof": "411.6",
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Treble damages under statute",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "713da219-defe-4738-95ff-9a0edb803963",
    "claim_title": "Contribution \u2013 Uniform Contribution Among Tortfeasors Act",
    "elements": [
      "Plaintiff is a tortfeasor;",
      "Plaintiff paid more than its fair share of a common liability;",
      "Defendant should have paid part of the liability borne by Plaintiff; and",
      "Plaintiff suffered damages in an amount equal to the excess share of the common liability paid by Plaintiff."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "412",
    "burden_of_proof": null,
    "claim_category": "procedural",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Contribution claim",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "e51d6d2c-6355-4f27-8042-4e38c879dad2",
    "claim_title": "Conversion",
    "elements": [
      "Defendant\u2019s unauthorized act;",
      "Deprives plaintiff of his or her property permanently or for an indefinite time; and",
      "The deprivation is inconsistent with plaintiff\u2019s ownership interest in the property."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "411",
    "burden_of_proof": "411.6",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Use civil theft pattern",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "e8f8a950-7589-4640-b8d0-ea40a7eda6d1",
    "claim_title": "Copyright Infringement",
    "elements": [
      "Plaintiff owns the copyright;",
      "Plaintiff\u2019s copyright is valid; and",
      "Defendant copied the copyrighted work without authorization."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Federal claim - may need federal instructions",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "181c0532-7d53-4f44-8b7a-c38abeb3e992",
    "claim_title": "Declaratory Judgment",
    "elements": [
      "A bona fide, actual, present practical need for declaration;",
      "The declaration should concern a present, ascertained or ascertainable state of facts or present controversy as to a state of facts;",
      "An immunity, power, privilege or right of the complaining party is dependent upon the facts or the law applicable to the facts;",
      "A person or persons have, or reasonably may have, an actual, present, adverse and antagonistic interest in the subject matter, either in fact or law;",
      "The antagonistic and adverse interest(s) are all before the court by proper process or class representation; and",
      "The relief sought is not merely giving of legal advice or the answer to questions propounded for curiosity."
    ],
    "element_count": 6,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "procedural",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": "Procedural; no standard verdict form",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "2de96b4a-69a5-4997-89da-ba7b5df2e1ec",
    "claim_title": "Defamation Libel",
    "elements": [
      "Defendant made a false and defamatory statement;",
      "Defendant published (written or orally) to a third party;",
      "Defendant made the defamatory statement with the requisite intent (negligence or malice); and",
      "Plaintiff suffered damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Use misrepresentation pattern",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "f52ad9fd-659c-4649-9b53-1a4f0e5ac964",
    "claim_title": "Defamation Per Se",
    "elements": [
      "Tends to subject persons to hatred, distrust, ridicule, contempt, or disgrace;",
      "Tends to injure a person in a trade or profession; or",
      "Attributes to a person either conduct, characteristics, or conditions incompatible with the proper exercise of a lawful business, trade, profession or office."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "Damages presumed",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "190eb7c4-37d1-49ae-b563-2ed6d949f7eb",
    "claim_title": "Defamation Slander",
    "elements": [
      "Defendant made a false and defamatory statement;",
      "Defendant published (written or orally) to a third party;",
      "Defendant made the defamatory statement with the requisite intent (negligence or malice); and",
      "Plaintiff suffered damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "29b23557-3435-4bbc-97d4-c646a8a35942",
    "claim_title": "Defamation by Implication",
    "elements": [
      "Juxtaposes a series of facts so as to imply a defamatory connection between them; or",
      "Creates a defamatory implication by omitting facts, such that he may be held responsible for the defamatory implication."
    ],
    "element_count": 2,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "89d4a176-fa1d-46aa-a565-27b76a03f121",
    "claim_title": "Dog Bite Common Law",
    "elements": [
      "Defendant had actual knowledge of a tenant\u2019s dog\u2019s presence;",
      "Defendant knew or should have known of the dog\u2019s vicious propensities;",
      "Plaintiff was attacked by the dog on the premises; and",
      "Plaintiff suffered damages caused by the attack."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "9c97e9d6-6df1-410f-b48a-26f0f9195af7",
    "claim_title": "Emotional Distress, Intentional Infliction",
    "elements": [
      "Defendant\u2019s conduct was intentional or reckless;",
      "Defendant\u2019s conduct was outrageous;",
      "Defendant\u2019s conduct caused emotional distress; and",
      "Plaintiff suffered severe emotional distress."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "410",
    "burden_of_proof": "410.8",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "76afa7b6-f6b0-41e2-8d73-935fa7e001ae",
    "claim_title": "Emotional Distress, Negligent Infliction",
    "elements": [
      "Plaintiff must suffer physical injury (impact);",
      "Plaintiff\u2019s physical injury must be caused by the psychological trauma;",
      "Plaintiff must be involved in some way in the event causing the injury to another; and",
      "Plaintiff must have a close personal relationship to directly injured person."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "420",
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Check 420.x instructions",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "008e439b-c7fd-4678-967c-182082f877f8",
    "claim_title": "Estoppel, Equitable",
    "elements": [
      "A representation by defendant (the party estopped), to plaintiff (the party claiming estoppel) as to a material fact;",
      "The representation is contrary to the condition of affairs later asserted by defendant;",
      "Plaintiff relies on the representation; and",
      "Plaintiff suffers detriment by a change in position as a result of the representation and reliance thereon."
    ],
    "element_count": 4,
    "verdict_form": "416.33",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "This is typically a defense; adapt if used as claim",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Affirmative Defense\u2014Equitable Estoppel",
    "has_explicit_template": true
  },
  {
    "claim_id": "f2e61853-c3d1-4943-a5d1-4dd7fd660166",
    "claim_title": "Estoppel, Promissory",
    "elements": [
      "Defendant (the promisor) made a misrepresentation of a material fact;,",
      "Defendant should reasonably expect to induce action or forbearance on the part of plaintiff (the promisee) or a third person;",
      "Defendant\u2019s misrepresentation induces such action or forbearance by plaintiff or a third person; and",
      "Plaintiff suffers a detriment caused by reliance on the misrepresentation."
    ],
    "element_count": 4,
    "verdict_form": "416.46",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Promissory Estoppel",
    "has_explicit_template": true
  },
  {
    "claim_id": "d91f4bb2-53f6-4afe-a382-2f603af77e05",
    "claim_title": "False Imprisonment",
    "elements": [
      "Defendant intended to confine the plaintiff;",
      "Defendant performed an act resulting in plaintiff\u2019s confinement; and",
      "Plaintiff was conscious of the confinement or resulting harm."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "407",
    "burden_of_proof": "407.7",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "f676f5c3-3e88-4a82-8b75-eba2fb770384",
    "claim_title": "Florida Consumer Collection Practices Act",
    "elements": [
      "The plaintiff has been the object of collection activity arising from a consumer debt;",
      "The defendant is a person attempting to collect the consumer debt; and",
      "The defendant has engaged in an act or omission prohibited by the FCCPA."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "FCCPA - statutory damages",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "b7ed8d2d-64ef-4285-ae0e-d08f4c75afb0",
    "claim_title": "Florida Deceptive and Unfair Trade Practices Act",
    "elements": [
      "A deceptive act or unfair practice;",
      "Causation; and",
      "Actual damages."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "FDUTPA - statutory damages/attorneys fees",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "61b2725c-b6bc-4aa3-bd23-90a27414e3e2",
    "claim_title": "Forcible Entry and Detention",
    "elements": [
      "Plaintiff was in possession of real property;",
      "Plaintiff was ousted of actual possession of the property; and",
      "Defendant withheld possession of the property from Plaintiff without their consent."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "property",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "53cf37dc-fcd4-470a-92e1-e87093139793",
    "claim_title": "Fraud",
    "elements": [
      "Defendant made a false statement regarding a material fact;",
      "Defendant knew or should have known the representation was false;",
      "Defendant intended that the representation induce plaintiff to act on it; and",
      "Plaintiff suffered damages in justifiable reliance on the representation."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "f0dd01f3-2953-4c5b-a2c1-30f4d44f3f82",
    "claim_title": "Fraud \u2013 Constructive",
    "elements": [
      "Plaintiff and Defendant share a confidential or fiduciary relationship;",
      "Defendant abused the relationship, or took unconscionable advantage of Plaintiff; and",
      "Plaintiff suffered damages as a result."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "49d3defa-b5d3-4beb-b050-621f550828e6",
    "claim_title": "Fraud \u2013 Fraud in the Performance",
    "elements": [
      "Defendant made a false statement regarding a material fact;",
      "Defendant knew or should have known the representation was false;",
      "Defendant intended that the representation induce plaintiff to act on it; and",
      "Plaintiff suffered damages in justifiable reliance on the representation."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "527f76fc-5a2c-4ec1-8dd0-25e2e413029a",
    "claim_title": "Fraud \u2013 Fraudulent Inducement",
    "elements": [
      "Defendant made a false statement regarding a material fact;",
      "Defendant knew or should have known the representation was false;",
      "Defendant intended that the representation induce plaintiff to act on it; and",
      "Plaintiff suffered damages in justifiable reliance on the representation."
    ],
    "element_count": 4,
    "verdict_form": "416.28",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": "416.28 is defense form; adapt for claim",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Affirmative Defense on Fraud in the Inducement",
    "has_explicit_template": true
  },
  {
    "claim_id": "ad3c74e1-6386-474f-a6cc-b7d392936d91",
    "claim_title": "Fraud \u2013 Fraudulent Misrepresentation",
    "elements": [
      "Defendant made a false statement regarding a material fact;",
      "Defendant knew or should have known the representation was false;",
      "Defendant intended that the representation induce plaintiff to act on it; and",
      "Plaintiff suffered damages acting in reliance on the representation."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "8e85fac3-0795-488a-84b6-782f8bc6f5f6",
    "claim_title": "Fraud \u2013 Negligent Misrepresentation",
    "elements": [
      "Defendant made a false statement regarding a material fact;",
      "Defendant knew or should have known the representation was false;",
      "Defendant intended that the representation induce plaintiff to act on it; and",
      "Plaintiff suffered damages in justifiable reliance on the representation."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "f215dd5f-8838-4076-af0c-31b5ae87ca9e",
    "claim_title": "Fraud, Aiding and Abetting",
    "elements": [
      "existence of the underlying fraud;",
      "knowledge of the fraud; and",
      "the defendant provided substantial assistance to the commission of the fraud."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": true,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "c64eb3e2-f974-4de6-9f53-cbc9a4a984f6",
    "claim_title": "Fraudulent Nondisclosure with Real Estate Transactions",
    "elements": [
      "The seller of a home must have knowledge of a defect in the property;",
      "The defect must materially affect the value of the property;",
      "The defect must be not readily observable and must be unknown to the buyer; and",
      "The buyer must establish that the seller failed to disclose the defect to the buyer.\u201d"
    ],
    "element_count": 4,
    "verdict_form": "416.42",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "fraud",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Duty to Disclose\u2014Residential",
    "has_explicit_template": true
  },
  {
    "claim_id": "905643d3-c5cc-4e02-bfc2-463a876a09b3",
    "claim_title": "Gross Negligence \u2013 Employee v. Employer",
    "elements": [
      "Imminent or clear and present danger amounting to a more than normal or usual peril;",
      "Defendant knew of the imminent danger; and",
      "An act or omission that evinces a conscious disregard of the consequences."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "8095ffa0-2717-4719-891c-da21264838bd",
    "claim_title": "Implied Way of Necessity",
    "elements": [
      "\u201c[W]here a person has heretofore granted or hereafter grants lands to which there is no accessible right-of way except over her or his land, or has heretofore retained or hereafter retains land which is inaccessible except over the land which the person conveys. In such instances a right-of-way is presumed to have been granted or reserved.\u201dHancock v. Tipton, 732 So. 2d 369, 373 (Fla. 2d DCA 1999) (citation omitted)."
    ],
    "element_count": 1,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "property",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "089d1512-1265-47d3-93c6-4d4cfc834de8",
    "claim_title": "Indemnification",
    "elements": [
      "Plaintiff discharges a duty owed to another party as a result of some vicarious, constructive, derivative or technical liability;",
      "Defendant should have discharged the duty satisfied by Plaintiff;",
      "Plaintiff is without any fault; and",
      "Plaintiff suffered in damages by discharging the liability that should be borne by Defendant."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "a1a0073c-f583-4255-9575-f04f6064e8a3",
    "claim_title": "Indemnification, Common Law",
    "elements": [
      "that they are wholly without fault;",
      "that the party from whom they are seeking indemnity is at fault; and",
      "that they are liable to the injured party only because they are vicariously, constructively, derivatively, or technically liable for the wrongful acts of the party from whom they are seeking indemnity."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "1c478947-2960-40df-a9b3-bc50ae1a85dc",
    "claim_title": "Indemnification, Contractual",
    "elements": [
      "The party filing the claim cannot be at fault;",
      "The other party must be at fault."
    ],
    "element_count": 2,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "46eabd91-73af-45ce-9f3f-f0224703b5df",
    "claim_title": "Injunction Permanent",
    "elements": [
      "It has suffered an irreparable injury;",
      "The remedies available at law, such as monetary damages, are inadequate to compensate for that injury;",
      "Considering the balance of hardships between the plaintiff and defendant, a remedy in equity is warranted; and",
      "The public interest would not be disserved by a permanent injunction."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "84f95b59-5e24-4f2a-b1ca-91f278ed63d2",
    "claim_title": "Injurious Falsehood",
    "elements": [
      "Defendant made a false and defamatory statement;",
      "Defendant published (written or orally) to a third party;",
      "Defendant made the defamatory statement with the requisite intent (negligence or malice); and",
      "Plaintiff suffered damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "890def6f-9f89-4fd6-bbe1-7c56212a11a2",
    "claim_title": "Interference with Child Custody",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "736d2f5f-3e6d-4703-a0de-7969dde7de9b",
    "claim_title": "Invasion of Privacy",
    "elements": [
      "Appropriation:Unauthorized use of a person\u2019s name or likeness to obtain some benefit.",
      "Intrusion:Physically or electronically intruding into one\u2019s private quarters or person.",
      "Public Disclosure of Private Facts:Publication of private facts that are offensive to the reasonable person and not of legitimate public concern."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "b58c2699-c4af-462c-a777-45e42756e278",
    "claim_title": "Invasion of Privacy \u2013 Appropriation",
    "elements": [
      "Appropriation:Unauthorized use of a person\u2019s name or likeness to obtain some benefit.",
      "Intrusion:Physically or electronically intruding into one\u2019s private quarters or person.",
      "Public Disclosure of Private Facts:Publication of private facts that are offensive to the reasonable person and not of legitimate public concern."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "c83e5822-0229-4509-85dd-eadef8934ed7",
    "claim_title": "Invasion of Privacy \u2013 Intrusion",
    "elements": [
      "Appropriation:Unauthorized use of a person\u2019s name or likeness to obtain some benefit.",
      "Intrusion:Physically or electronically intruding into one\u2019s private quarters or person.",
      "Public Disclosure of Private Facts:Publication of private facts that are offensive to the reasonable person and not of legitimate public concern."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "7bfb645b-3193-4549-af12-14ac755400b4",
    "claim_title": "Invasion of Privacy \u2013 Public Disclosure of Private Facts",
    "elements": [
      "publication to a large number of people,",
      "of private facts",
      "whose publication would be highly offensive to a reasonable person and",
      "are not of public concern.",
      "False Light:Publication of facts that place a person in a false light even though the facts themselves may not be defamatory."
    ],
    "element_count": 5,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "a2522cce-f65f-41de-b28d-3047c48a7369",
    "claim_title": "Legal Malpractice",
    "elements": [
      "The Defendant attorney was employed by Plaintiff;",
      "The Defendant neglected a reasonable duty owed to Plaintiff;",
      "The Defendant\u2019s negligence was the proximate cause of Plaintiff\u2019s damage, which is the amount Plaintiff would have recovered but for the Defendant\u2019s negligence; and",
      "Plaintiff suffered damage."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "402",
    "burden_of_proof": "402.13",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "ad19aaca-b1f7-457b-b465-ca6aa96f673d",
    "claim_title": "Lien \u2013 Charging",
    "elements": [
      "an express or implied contract between attorney and client;",
      "an express or implied understanding for payment of attorney\u2019s fees out of the recovery;",
      "either an avoidance of payment or a dispute as to the amount of fees; and",
      "timely notice."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "02016122-3d6d-4af5-ba86-edd228aa4d4f",
    "claim_title": "Lien \u2013 Retaining",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "67e94861-511d-4112-a26f-e2510d76c917",
    "claim_title": "Loss of Consortium \u2013 Child",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Derivative claim",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "52f6eecb-4956-4e94-a68d-52be8a3d2d05",
    "claim_title": "Loss of Consortium \u2013 Spouse",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Derivative claim",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "f2d0efc2-370d-4d81-8f6f-609c9523b654",
    "claim_title": "Malicious Prosecution",
    "elements": [
      "Defendant commenced or continued an original criminal or civil judicial proceeding;",
      "Defendant was the legal cause of the original proceeding against the Plaintiff;",
      "The bona fide termination of the original proceeding in favor of the Plaintiff;",
      "Absence of probable cause in the original proceeding;",
      "Defendant acted with malice; and",
      "Plaintiff suffered damages"
    ],
    "element_count": 6,
    "verdict_form": null,
    "category_instruction": "406",
    "burden_of_proof": "406.9",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": true,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "0a803009-9413-4e57-8d91-2294354bce17",
    "claim_title": "Misleading Advertisement",
    "elements": [
      "Misrepresentation of a material fact;",
      "The person knew or should have known that the fact was being misrepresented;",
      "The person intended to induce the other reliance; and",
      "The other\u2019s justifiable reliance caused him to suffer damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "becf8147-f88f-4cef-99eb-31e62b46980c",
    "claim_title": "Money Lent",
    "elements": [
      "Plaintiff delivered money to Defendant;",
      "The money was intended as a loan; and",
      "Defendant has not repaid the money."
    ],
    "element_count": 3,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1",
      "504.6"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "b8db2bba-5ec9-427c-8dbd-0aa30a10cef0",
    "claim_title": "Negligence",
    "elements": [
      "Defendant owed a duty to plaintiff to protect the plaintiff from a particular injury or damage;",
      "Defendant breached this duty;",
      "Defendant\u2019s breach was the proximate cause of injury or damage to plaintiff; and",
      "Plaintiff suffered damages caused by the breach."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "63265097-05d5-4fa8-b32d-67e4a4c8f691",
    "claim_title": "Negligence Fall Down",
    "elements": [
      "Defendant owed a duty to plaintiff to protect the plaintiff from a particular injury or damage;",
      "Defendant breached this duty;",
      "Defendant\u2019s breach was the proximate cause of injury or damage to plaintiff; and",
      "Plaintiff suffered damages caused by the breach."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "1581df33-472e-499a-ac6c-e797f69c1844",
    "claim_title": "Negligence Motor Vehicle",
    "elements": [
      "Defendant owed a duty to plaintiff to protect the plaintiff from a particular injury or damage;",
      "Defendant breached this duty;",
      "Defendant\u2019s breach was the proximate cause of injury or damage to plaintiff; and",
      "Plaintiff suffered damages caused by the breach."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "9e84e8ba-103a-4330-ab56-835e29ce283f",
    "claim_title": "Negligence Stillbirth",
    "elements": [
      "Plaintiff\u2019s child was stillborn;",
      "Defendant\u2019s negligence caused the stillbirth of the child; and",
      "Plaintiff suffered mental pain and anguish as a result."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "502.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "88704cbb-ad64-487b-b76d-fd0b1b4202a3",
    "claim_title": "Negligent Destruction of Evidence",
    "elements": [
      "Plaintiff has a potential civil action;",
      "Defendant has a legal or contractual duty to preserve evidence that is relevant to the potential action;",
      "The evidence is destroyed;",
      "The destruction of the evidence significantly impairs Plaintiff\u2019s ability to prove her case;",
      "A causal relationship between the evidence destruction and Plaintiff\u2019s inability to prove her case; and",
      "Damages."
    ],
    "element_count": 6,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "469cd0d0-1c8c-469d-93ea-f49623282ed0",
    "claim_title": "Negligent Entrustment",
    "elements": [
      "R. Civ. P. 1.110(d) (pleading affirmative defenses), and other standard defenses. See \u00a7 1.",
      "Statute of Limitations:95.11(3), Fla. Stat. (four years).",
      "Knowledge or privityis necessary to be liable for negligent entrustment.Matter of Offshore of the Palm Beaches, Inc., 2011 WL 13228105, *1 (S.D. Fla. Feb. 16, 2011);Suzuki of Orange Park, Inc. v. Shubert, 86 F.3d 1060, 1064 (11th Cir. 1996).",
      "An exception for a negligent entrustmentclaims related to car accidents is that: \u201cIf the driver were found not to be negligent, the owner could not be held vicariously liable.\u201dSanchez v. Disc. Rock & Sand Inc., 2022 WL 832429, *7 (S.D. Fla. Feb. 9, 2022)(citingClooney v. Geeting, 352 So. 2d 1216, 1220 (Fla. 2d DCA 1977))(emphasis added).",
      "\u201c[F]oreseeability of harm, rather than ownership, determine[s] whether an action exist[s] for negligent entrustment.\u201dMatter of the Complaint of Gozleveli, 2015 WL 12549148, *3 (S.D. Fla. Mar. 31, 2015) (citingKitchen v. K-Mart Corp., 697 So. 2d 1200, 1205 (Fla. 1997))(emphasis added).",
      "\u201cBecause of the damage cap, a negligent entrustment or hiring claim can nowsubject the employer to additional damages in excess of their vicarious liability, restricted to the employer\u2019s percentage of fault under comparative negligence principles.\u201dMurray v. Britton, 2022 WL 17820387, *3 (M.D. Fla. Dec. 20, 2022)(emphasis added);Trevino v. Mobley, 63 So. 3d 865, 867 (Fla. 5th DCA 2011).",
      "\u201c[A]n essential element of a negligent entrustment cause of action is that the person charged with liabilityhave a superior right to control the property.\u201dWeber ex rel. Estate of Weber v. Marino Parking Sys., Inc., 100 So. 3d 729, 730 (Fla. 2d DCA 2012) (citation omitted)(emphasis added).",
      "\u201cFor a claim of negligent entrustment to properly lie,the defendant must be negligent(i.e., he knew or should have known)at the time of the initial entrustment, not after the fact.\u201dRuano v. Water Sports of Am., Inc., 578 So. 2d 385, 386 (Fla. 3d DCA 1991)(emphasis added).",
      "\u201c[T]ort liability in Florida is premised on purecomparativenegligence, which means that a jury should apportion fault between the plaintiff, defendant, and any third parties alleged to have been at fault, and render an award based on a defendant\u2019s percentage of fault in causing an injury.\u201dWilliams v. Davis, 974 So. 2d 1052, 1061 n.1 (Fla. 2007); Fla. Stat. \u00a7 768.81(2).",
      "Florida\u2019sAlcohol and Drug Defense, as set forth in Section 768.36(2), Fla. Stat., provides in pertinent part that \u201c[i]n any civil action, a plaintiff may not recover any damages for loss or injury to his or her person or property if the trier of fact finds that, at the time the plaintiff was injured: (a) The plaintiff was under the influence of any alcoholic beverage or drug to the extent that the plaintiff\u2019s normal faculties were impaired or the plaintiff had a blood or breath alcohol level of 0.08 percent or higher; and (b) As a result of the influence of such alcoholic beverage or drug the plaintiff was more than 50 percent at fault for his or her own harm.\u201dMain St. Entm\u2019t, Inc. v. Faircloth, 342 So. 3d 232, 237 (Fla. 1st DCA 2022);Kempton v. McComb, 264 So.3d 1180, 1181 (Fla. 5th DCA 2019);see alsoBryant v. Mascara, No. 2:16-CV-14072-ROSENBERG/REINHART, 2018 WL 3862650, at *1 (S.D. Fla. Aug. 14, 2018)."
    ],
    "element_count": 25,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "ff2e5224-0884-49cd-a189-39709bfeb280",
    "claim_title": "Negligent Retention",
    "elements": [
      "The defendant employer becomes aware, or should have become aware, of problems with an employee that indicates his unfitness;",
      "The defendant employer owes a duty to plaintiff to protect the plaintiff from a particular injury or damage;",
      "The defendant employer breaches its duty by failing to take further action, such as investigation, discharge, or reassignment;",
      "Defendant\u2019s breach was the proximate cause of injury or damage to plaintiff; and",
      "Plaintiff suffered damages as a result of the breach."
    ],
    "element_count": 5,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "0fd73803-b4c4-4010-876d-c7a79a2deeda",
    "claim_title": "Negligent Security",
    "elements": [
      "Defendant owed a duty to plaintiff to protect the plaintiff from a particular injury or damage;",
      "Defendant breached this duty;",
      "Defendant\u2019s breach was the proximate cause of injury or damage to plaintiff; and",
      "Plaintiff suffered damages caused by the breach."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "e210c2c8-1171-49f8-8c5b-9609880084e4",
    "claim_title": "Negligent Supervision",
    "elements": [
      "The defendant employer becomes aware, or should have become aware, of problems with an employee that indicates his unfitness;",
      "The defendant employer owes a duty to plaintiff to protect the plaintiff from a particular injury or damage;",
      "The defendant employer breaches its duty by failing to take further action, such as investigation, discharge, or reassignment;",
      "Defendant\u2019s breach was the proximate cause of injury or damage to plaintiff; and",
      "Plaintiff suffered damages as a result of the breach."
    ],
    "element_count": 5,
    "verdict_form": null,
    "category_instruction": "401",
    "burden_of_proof": "401.21",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "f7a8da84-a61d-4fca-a2c9-b1a5e3b487dd",
    "claim_title": "Open Account",
    "elements": [
      "A contract exists between a creditor Plaintiff and debtor Defendant;",
      "The amount claimed as owing by Plaintiff represents an agreed upon sales price for goods, or the reasonable value of goods delivered; and",
      "The goods were actually delivered."
    ],
    "element_count": 3,
    "verdict_form": "416.38",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Open Account",
    "has_explicit_template": true
  },
  {
    "claim_id": "2c329943-4dcf-470b-ab96-44e9a7ec9db8",
    "claim_title": "Private Nuisance",
    "elements": [
      "Defendant\u2019s property use is unreasonable under the circumstances; and",
      "There is an appreciable, substantial, tangible injury resulting in actual, material, physical discomfort or interference with the enjoyment and value of private property rights of the Plaintiff."
    ],
    "element_count": 2,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "c63f9c92-c8f0-4325-a2e6-3e2d8f56b636",
    "claim_title": "Professional Negligence",
    "elements": [
      "Defendant had a duty towards the plaintiff;",
      "Defendant breached the duty; and",
      "The breach resulted in damages to the Plaintiff."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": "402",
    "burden_of_proof": "402.13",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "92b0b004-0b63-4c7b-9008-eac46fdb6e2a",
    "claim_title": "Public Nuisance",
    "elements": [
      "Nuisance violates public rights, subverts public order, decency or morals; or",
      "Causes inconvenience or damage to the public generally; and",
      "Plaintiff suffers a special injury different in degree or kind from the damage suffered by the public."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "5ab1c1bc-88d4-4f59-982d-adafc76527a2",
    "claim_title": "Public Records Act",
    "elements": [
      "Plaintiff made a specific request for public records;",
      "the agency from which the records were requested is a public agency as defined in Section 119.011(2);",
      "the agency has custody of the requested records;",
      "the requested records are not exempt under Section 119.07; and",
      "the agency failed or refused to comply with the request or caused an unjustified delay in providing the requested records."
    ],
    "element_count": 5,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Attorneys fees available",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "7ee3f221-2d2a-4617-86b9-4e7865096786",
    "claim_title": "Quantum Meruit",
    "elements": [
      "Absence of an express agreement;",
      "Plaintiff provided a benefit in the form of goods and services accepted by the defendant;",
      "Under ordinary circumstances a reasonable person would reasonably expect to pay for such benefit;",
      "Defendant failed to pay for the benefit; and",
      "Damages."
    ],
    "element_count": 5,
    "verdict_form": "416.7",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Contract Implied in Law",
    "has_explicit_template": true
  },
  {
    "claim_id": "d9b0969a-cd31-4d4c-8260-b33e2f95a862",
    "claim_title": "Quiet Title",
    "elements": [
      "The Plaintiff has title to the property,",
      "A cloud exists, and",
      "The plaintiff\u2019s title is valid, and the cloud is invalid."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "property",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "1880b6a6-958b-4ef1-ad5d-f6b726b0e419",
    "claim_title": "Replevin",
    "elements": [
      "A description of the claimed property that is sufficient to make possible its identification and a statement, to the best knowledge, information, and belief of the plaintiff of the value of such property and its location.",
      "A statement that the plaintiff is the owner of the claimed property or is entitled to possession of it, describing the source of such title or right. If the plaintiff\u2019s interest in such property is based on a written instrument, a copy of said instrument must be attached to the complaint.",
      "A statement that the property is wrongfully detained by the defendant, the means by which the defendant came into possession thereof, and the cause of such detention according to the best knowledge, information, and belief of the plaintiff.",
      "A statement that the claimed property has not been taken for a tax, assessment, or fine pursuant to law."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "property",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "d765b42e-f8bf-4e8b-8c54-9590bd338f48",
    "claim_title": "Rescission",
    "elements": [
      "The character or relationship of the parties;",
      "The making of the contract;",
      "The existence of fraud, mutual mistake, false representation, impossibility of performance, or other ground for rescission or cancellation;",
      "Plaintiff has rescinded the contract and notified defendant of such rescission;",
      "If the plaintiff has received benefits from the contract, the plaintiff should further allege an offer to restore those benefits to the defendant, if restoration is possible; and",
      "Plaintiff has no adequate remedy at law."
    ],
    "element_count": 6,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": false,
    "notes": "Equitable remedy",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "bd5055cb-6eb4-432f-a923-e7728906c8c7",
    "claim_title": "Slander of Title",
    "elements": [
      "Defendant communicated to a third person;",
      "A statement disparaging plaintiff\u2019s title;",
      "The statement is untrue; and",
      "Defendant\u2019s communication caused plaintiff to suffer actual damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "409",
    "burden_of_proof": "409.10",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "6e98b661-cbd2-4dda-992c-b97cc608f826",
    "claim_title": "Specific Performance",
    "elements": [
      "Plaintiff and Defendant are parties to a contract;",
      "Plaintiff performed its obligation under the contract or is ready, willing and able to perform;",
      "Defendant refused to perform its obligation under the contract; and",
      "No adequate remedy at law exists."
    ],
    "element_count": 4,
    "verdict_form": "416.4.",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": false,
    "notes": "Equitable remedy; damages not typical",
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Breach of Contract",
    "has_explicit_template": true
  },
  {
    "claim_id": "6dfa9ff2-ef77-45db-9af2-1585c46465ea",
    "claim_title": "Statutory Way of Necessity",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "property",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "05229f49-6543-4e09-8119-5ff75736610d",
    "claim_title": "Strict Liability",
    "elements": [
      "Manufacturer or seller places a defective product on the market;",
      "The defective product is sold in an unreasonably dangerous condition;",
      "The product reaches the plaintiff without substantial change in the condition in which the product is sold; and",
      "The defect is the proximate cause of the plaintiff\u2019s injury."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "403",
    "burden_of_proof": "403.17",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "659a9e32-c5ae-47cc-acfd-ac5a07b48ad5",
    "claim_title": "Strict Liability \u2013 Design Defect",
    "elements": [
      "Manufacturer or seller places a defective product on the market;",
      "The defective product is sold in an unreasonably dangerous condition;",
      "The product reaches the plaintiff without substantial change in the condition in which the product is sold; and",
      "The defect is the proximate cause of the plaintiff\u2019s injury."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "403",
    "burden_of_proof": "403.17",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "c9e61b76-aae8-423e-97bf-305ecfa13b8e",
    "claim_title": "Strict Liability \u2013 Failure to Warn",
    "elements": [
      "Manufacturer or seller places a defective product on the market;",
      "The defective product is sold in an unreasonably dangerous condition;",
      "The product reaches the plaintiff without substantial change in the condition in which the product is sold; and",
      "The defect is the proximate cause of the plaintiff\u2019s injury."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "403",
    "burden_of_proof": "403.17",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "c1b5f659-c06d-4d8a-8d9f-e790e1889096",
    "claim_title": "Strict Liability \u2013 Manufacturing Defect",
    "elements": [
      "Manufacturer or seller places a defective product on the market;",
      "The defective product is sold in an unreasonably dangerous condition;",
      "The product reaches the plaintiff without substantial change in the condition in which the product is sold; and",
      "The defect is the proximate cause of the plaintiff\u2019s injury."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "403",
    "burden_of_proof": "403.17",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.3",
      "501.4",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "021a89f0-fa11-41fe-a8ec-0ef492c33e4e",
    "claim_title": "Subrogation, Equitable",
    "elements": [
      "Plaintiff is subrogated to the rights of the injured party (the \u201csubrogee\u201d);",
      "The subrogee made the payment to protect his or her own interest,",
      "The subrogee did not act as a volunteer,",
      "The subrogee was not primarily liable for the debt,",
      "The subrogee paid off the entire debt,",
      "Subrogation would not work any injustice to the rights of a third party, and",
      "As a result, the subrogee (party discharging the debt) stands in the shoes of the person whose claims have been discharged and thus succeeds to the right and priorities of the original creditor."
    ],
    "element_count": 7,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "01e61fc2-192e-44cc-af80-e7fdd06a0d85",
    "claim_title": "Temporary Injunction",
    "elements": [
      "Plaintiff will suffer irreparable harm;",
      "Plaintiff has no adequate remedy at law;",
      "Plaintiff has a substantial likelihood of success on the merits; and",
      "A temporary injunction will serve the public interest."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "4175e0e1-61eb-4b8e-a944-be2d4d8a4c32",
    "claim_title": "Tortious Interference: 1. With Advantageous Business Relationship",
    "elements": [
      "Plaintiff has a business relationship, not necessarily evidenced by an enforceable contract;",
      "Defendant has knowledge of the relationship;",
      "Defendant intentionally and unjustifiably interfered with the relationship; and",
      "Plaintiff suffered damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "408",
    "burden_of_proof": "408.6",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5",
      "504.3"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "ed460912-126e-49ea-b7d7-1125101a7aa9",
    "claim_title": "Tortious Interference: 2. With a Contractual Right",
    "elements": [
      "The existence of contract to which plaintiff is a party;",
      "Defendant\u2019s knowledge of the contract;",
      "Defendant\u2019s intentional procurement of the contract\u2019s breach;",
      "The absence of justification or privilege; and",
      "Plaintiff suffered damages resulting from the breach."
    ],
    "element_count": 5,
    "verdict_form": null,
    "category_instruction": "408",
    "burden_of_proof": "408.5",
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5",
      "504.3"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "fd788106-02a1-4365-8c67-aea5fa0e107c",
    "claim_title": "Tortious Interference: 3. With a Dead Body",
    "elements": [
      "Defendant unlawfully interfered with a dead body, including;",
      "Interference with the burial, sepulcher, or other lawful disposition of the dead body;",
      "Defendant\u2019s conduct was extreme and outrageous so as to imply malice;",
      "A surviving relative suffered emotional distress as a result."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "3b907abf-4247-4cec-b47c-23b98e047b94",
    "claim_title": "Tortious Interference: 4. With the Parent-Child Relationship",
    "elements": [
      "An intentional effort by the defendant to detract the child from the parent\u2019s custody or service;",
      "The effort was willful; and",
      "The defendant knowingly invaded the child\u2019s parent\u2019s rights."
    ],
    "element_count": 3,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "ad114d38-7e8f-4fc1-a3bb-013670bc5902",
    "claim_title": "Trade Dress Infringement",
    "elements": [
      "Plaintiff is the prior user of the trade dress;",
      "Plaintiff\u2019s trade dress is inherently distinctive or has acquired secondary meaning;",
      "The features of the plaintiff\u2019s trade dress are primarily non-functional; and",
      "Plaintiff\u2019s and defendant\u2019s trade dress are confusingly similar."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "5ea43e9d-1882-4251-b03c-f7a67facb75a",
    "claim_title": "Trespass",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": "452",
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "fbdc6c74-67a9-45bb-9228-c43165acf6f9",
    "claim_title": "Trusts, Constructive Trust",
    "elements": [
      "Plaintiff and defendant share a confidential relationship through which;",
      "Defendant makes a promise, express or implied;",
      "To transfer property to the plaintiff and causing reliance thereon; and",
      "Defendant is unjustly enriched by failing to deliver the property."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "1f9e7d73-d0e8-457e-bf09-947b95f0b170",
    "claim_title": "Trusts, Resulting Trust",
    "elements": [
      "The parties actually intend to create a trust relationship;",
      "The parties fail to execute documents creating, or establish adequate evidence of the intent to create, a trust."
    ],
    "element_count": 2,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "equitable",
    "damages_instructions": [],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": true,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "5cffd9b4-ccc1-4add-b9b7-523fe25ff5e1",
    "claim_title": "Unfair Competition",
    "elements": [
      "Plaintiff is the prior user of the trade name, service mark or trade mark (collectively, \u201ctrade symbol\u201d);",
      "Plaintiff\u2019s trade symbol is arbitrary or suggestive or has acquired secondary meaning;",
      "Defendant is using a confusingly similar trade symbol to identify a similar good marketed or services rendered in competition with the plaintiff in the same area of the plaintiff\u2019s established trade symbol; and",
      "Defendant\u2019s actions will likely cause consumer confusion as to the sponsorship of the good or service."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "a7b1c3ea-9552-478a-872f-c808a0835402",
    "claim_title": "Unfair Competition",
    "elements": [
      "Plaintiff is the prior user of the trade name, service mark or trade mark (collectively, \u201ctrade symbol\u201d);",
      "Plaintiff\u2019s trade symbol is arbitrary or suggestive or has acquired secondary meaning;",
      "Defendant is using a confusingly similar trade symbol to identify a similar good marketed or services rendered in competition with the plaintiff in the same area of the plaintiff\u2019s established trade symbol; and",
      "Defendant\u2019s actions will likely cause consumer confusion as to the sponsorship of the good or service."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "448be625-a951-4186-8398-bc481b3d099a",
    "claim_title": "Unjust Enrichment",
    "elements": [
      "Plaintiff has conferred a benefit on the defendant, who has knowledge thereof;",
      "Defendant voluntarily accepts and retains the benefit conferred; and",
      "The circumstances render the defendant\u2019s retention of the benefit inequitable unless the defendant pays to the plaintiff the value of the benefit."
    ],
    "element_count": 3,
    "verdict_form": "416.7",
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "contract",
    "damages_instructions": [
      "504.1"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped",
    "verdict_form_title": "Model Form of Verdict for Contract Implied in Law",
    "has_explicit_template": true
  },
  {
    "claim_id": "ee0decd7-330f-498d-a65b-26e3984c2802",
    "claim_title": "Usurious Transaction",
    "elements": [
      "There must be a loan express or implied;",
      "An understanding between the parties that the money lent shall be returned;",
      "That for such a loan a greater rate of interest than is allowed by law shall be paid or agreed to be paid, as the case may be; and",
      "There must exist a Corrupt intent to take more than the legal rate for the use of the money loaned."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "7e2689b8-38a9-4876-a79a-666f7a4823e1",
    "claim_title": "Worthless Check",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "statutory",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": "Statutory treble damages",
    "mapping_status": "mapped"
  },
  {
    "claim_id": "cdad10e1-f901-4311-8809-9e66bf80304b",
    "claim_title": "Wrongful Birth",
    "elements": [],
    "element_count": 0,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2",
      "501.5"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "5ab42b47-e170-4872-a92e-1fe4fe260ffb",
    "claim_title": "Wrongful Death",
    "elements": [
      "Defendant owed a legal duty to the decedent;",
      "Defendant breached that duty;",
      "Defendant\u2019s breach was the proximate cause of death; and",
      "Damages."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": "502",
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "502.1",
      "502.2",
      "502.3",
      "502.4"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": false,
    "notes": null,
    "mapping_status": "mapped"
  },
  {
    "claim_id": "b97e82e9-cbde-4651-bb6c-ee9972793848",
    "claim_title": "Wrongful Interference with Testamentary Expectancy",
    "elements": [
      "Plaintiff had an expectancy to be a beneficiary of and receive property from a testator\u2019s estate;",
      "Defendant intentional interfered with the expectancy through tortious conduct, including duress, fraud or undue influence;",
      "Defendant\u2019s actions caused Plaintiff to suffer damage; and",
      "Plaintiff suffered damage."
    ],
    "element_count": 4,
    "verdict_form": null,
    "category_instruction": null,
    "burden_of_proof": null,
    "claim_category": "tort",
    "damages_instructions": [
      "501.2"
    ],
    "allows_punitive": false,
    "requires_clear_and_convincing": false,
    "equitable_relief": false,
    "generate_from_elements": true,
    "notes": null,
    "mapping_status": "mapped"
  }
]
""")

# %%
len(claim_damages)
# Out:
# 108

# %%
with open('terraform/data/claims.json') as f:
    claims = json.load(f)

# %%
with open('terraform/data/standard_jury_instructions.json') as f:
    standard_jury_instructions = json.load(f)

# %%
for claim in claims:
    damages_info = deepcopy([d for d in claim_damages if d['claim_id'] == claim['id']][0])

    del damages_info['claim_id']
    del damages_info['claim_title']
    del damages_info['elements']
    del damages_info['element_count']

    claim['damages'] = damages_info
